# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = {
    "logistic_regression": {
        "accuracy": 0.7981520966595593,
        "precision": 0.65625,
        "recall": 0.5053475935828877,
        "f1": 0.5709969788519638,
        "roc_auc": 0.8342841316760797,
    },
    "random_forest": {
        "accuracy": 0.7647476901208244,
        "precision": 0.8909090909090909,
        "recall": 0.13101604278074866,
        "f1": 0.22843822843822845,
        "roc_auc": 0.8239267281320697,
    },
    "xgboost": {
        "accuracy": 0.7931769722814499,
        "precision": 0.6627450980392157,
        "recall": 0.45187165775401067,
        "f1": 0.5373608903020668,
        "roc_auc": 0.8243059258377292,
    },
    "lightgbm": {
        "accuracy": 0.7874911158493249,
        "precision": 0.6470588235294118,
        "recall": 0.4411764705882353,
        "f1": 0.5246422893481717,
        "roc_auc": 0.8285625171480191,
    },
    "catboost": {
        "accuracy": 0.7953091684434968,
        "precision": 0.6557971014492754,
        "recall": 0.4839572192513369,
        "f1": 0.556923076923077,
        "roc_auc": 0.8333665508797905,
    },
}

results_df = pd.DataFrame(results).T.reset_index().rename(columns={"index": "model"})
results_df
# Out:
#                  model  accuracy  precision    recall        f1   roc_auc
# 0  logistic_regression  0.798152   0.656250  0.505348  0.570997  0.834284
# 1        random_forest  0.764748   0.890909  0.131016  0.228438  0.823927
# 2              xgboost  0.793177   0.662745  0.451872  0.537361  0.824306
# 3             lightgbm  0.787491   0.647059  0.441176  0.524642  0.828563
# 4             catboost  0.795309   0.655797  0.483957  0.556923  0.833367

# %%
results_df.plot(
    kind="bar",
    figsize=(12,6)
)

plt.title("Model Comparison")
plt.ylabel("ROC-AUC")
plt.show()
